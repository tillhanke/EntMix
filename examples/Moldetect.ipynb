# %%
using Chemfiles
using EntMix

# %%
traj = Trajectory("test.lammpstrj")
frame = read_step(traj, 1)
# Out:
# Frame(Chemfiles.CxxPointer{Chemfiles.lib.CHFL_FRAME}(Ptr{Chemfiles.lib.CHFL_FRAME} @0x000000002565db90, false))

# %%
Molecule.type_from_name!(frame)
Molecule.get_molecules(frame)
# Out:
# 2000-element Vector{Vector{Int64}}:
#  [0, 7, 6, 2, 11, 10, 4, 16, 15, 14, 1, 9, 8, 3, 13, 12, 5, 19, 18, 17]
#  [20, 27, 26, 22, 31, 30, 24, 36, 35, 34, 21, 29, 28, 23, 33, 32, 25, 39, 38, 37]
#  [40, 47, 46, 42, 51, 50, 44, 56, 55, 54, 41, 49, 48, 43, 53, 52, 45, 59, 58, 57]
#  [60, 67, 66, 62, 71, 70, 64, 76, 75, 74, 61, 69, 68, 63, 73, 72, 65, 79, 78, 77]
#  [80, 87, 86, 82, 91, 90, 84, 96, 95, 94, 81, 89, 88, 83, 93, 92, 85, 99, 98, 97]
#  [100, 107, 106, 102, 111, 110, 104, 116, 115, 114, 101, 109, 108, 103, 113, 112, 105, 119, 118, 117]
#  [120, 127, 126, 122, 131, 130, 124, 136, 135, 134, 121, 129, 128, 123, 133, 132, 125, 139, 138, 137]
#  [140, 147, 146, 142, 151, 150, 144, 156, 155, 154, 141, 149, 148, 143, 153, 152, 145, 159, 158, 157]
#  [160, 167, 166, 162, 171, 170, 164, 176, 175, 174, 161, 169, 168, 163, 173, 172, 165, 179, 178, 177]
#  [180, 187, 186, 182, 191, 190, 184, 196, 195, 194, 181, 189, 188, 183, 193, 192, 185, 199, 198, 197]
# ...

# %%
frame = read_step(traj, 8)
# Out:
# Frame(Chemfiles.CxxPointer{Chemfiles.lib.CHFL_FRAME}(Ptr{Chemfiles.lib.CHFL_FRAME} @0x0000000026e577c0, false))

# %%
Molecule.type_from_name!(frame)
molecules = Molecule.get_molecules(frame)
# Out:
# 2000-element Vector{Vector{Int64}}:
#  [0, 7, 6, 2, 11, 10, 4, 16, 15, 14, 1, 9, 8, 3, 13, 12, 5, 19, 18, 17]
#  [20, 27, 26, 22, 31, 30, 24, 36, 35, 34, 21, 29, 28, 23, 33, 32, 25, 39, 38, 37]
#  [40, 47, 46, 42, 51, 50, 44, 56, 55, 54, 41, 49, 48, 43, 53, 52, 45, 59, 58, 57]
#  [60, 67, 66, 62, 71, 70, 64, 76, 75, 74, 61, 69, 68, 63, 73, 72, 65, 79, 78, 77]
#  [80, 87, 86, 82, 91, 90, 84, 96, 95, 94, 81, 89, 88, 83, 93, 92, 85, 99, 98, 97]
#  [100, 107, 106, 102, 111, 110, 104, 116, 115, 114, 101, 109, 108, 103, 113, 112, 105, 119, 118, 117]
#  [120, 127, 126, 122, 131, 130, 124, 136, 135, 134, 121, 129, 128, 123, 133, 132, 125, 139, 138, 137]
#  [140, 147, 146, 142, 151, 150, 144, 156, 155, 154, 141, 149, 148, 143, 153, 152, 145, 159, 158, 157]
#  [160, 167, 166, 162, 171, 170, 164, 176, 175, 174, 161, 169, 168, 163, 173, 172, 165, 179, 178, 177]
#  [180, 187, 186, 182, 191, 190, 184, 196, 195, 194, 181, 189, 188, 183, 193, 192, 185, 199, 198, 197]
# ...

# %%
Molecule.mol_dictionary(frame, molecules)
# Out:
# Dict{Int64, Int64} with 25000 entries:
#   24824 => 1965
#   11950 => 598
#   1703  => 86
#   12427 => 622
#   7685  => 385
#   18374 => 919
#   3406  => 171
#   23970 => 1795
#   1090  => 55
#   2015  => 101
#   18139 => 907
#   17088 => 855
#   11280 => 565
#   16805 => 841
#   3220  => 162
#   11251 => 563
#   422   => 22
#   15370 => 769
#   15859 => 793
#   4030  => 202
#   8060  => 404
#   14167 => 709
#   8660  => 434
#   18475 => 924
#   14221 => 712
#   ⋮     => ⋮
